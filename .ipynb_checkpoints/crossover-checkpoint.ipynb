# %%
import pandas as pd
import seaborn as sns
sns.set_style("white", {
        "font.family": "serif",
        "font.serif": ["Times", "Palatino", "serif"]
})
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('totals', names = ['id','t','p','m','px','s'])
df
# Out:
#              id             t             p     m        px       s
# 0   jjlonga45vu  47606.019277  46697.246108  [31]  0.022279  1.0000
# 1   jjlongo67p5  46941.880463  46685.358747  [31]  0.022363  1.0000
# 2   jjlongqjtl4  46074.926853  44263.769318  [31]  0.040478  1.0000
# 3   jjlongt5y5l  44283.194750  46669.970370  [31]  0.022914  1.0000
# 4   jjlongx921h  42428.280618  46693.633188  [31]  0.022783  1.0000
# 5   jjlongnhqte  48945.271002  46668.890279  [31]  0.022473  1.0000
# 6   jjlongko6jy  48774.197084  46684.359029  [31]  0.022313  1.0000
# 7   jjlongusy78  46526.191957  46643.430132  [31]  0.022873  1.0000
# 8   jjlonghu4tb  48749.597808  46715.196070  [31]  0.022041  1.0000
# 9   jjlong6briu  46381.382917  46689.564501  [31]  0.022458  1.0000
# 10  jjlong9pt5x  76667.505741  85053.344637  [31]  0.000911  0.0100
# 11  jjlonge5c5h  80550.786972  70910.485909  [31]  0.000912  0.0100
# 12  jjlong1ulun  76878.572464  82120.960215  [31]  0.000663  0.0100
# 13  jjlongn6nd1  82015.210390  81999.181308  [31]  0.000653  0.0100
# 14  jjlongdrnex  75236.596584  81353.220434  [31]  0.000607  0.0100
# 15  jjlongz1zdp  79855.813980  80953.750333  [31]  0.000621  0.0100
# 16  jjlongs8t3o  81067.363739  81283.184928  [31]  0.000613  0.0100
# 17  jjlongwf8za  79389.118195  81624.170925  [31]  0.000600  0.0100
# 18  jjlonglxkkr  81159.510374  81334.885423  [31]  0.000608  0.0100
# 19  jjlong1fqb2  77534.364700  85647.727397  [31]  0.000608  0.0100
# 20  jjlongs9lyw  57977.550983  59861.859885  [31]  0.001325  0.0200
# 21  jjlongo631r  63124.350071  61437.934169  [31]  0.001200  0.0200
# 22  jjlongf5om4  56606.104374  61416.139193  [31]  0.001189  0.0200
# 23  jjlonglxr27  60100.079298  62060.285174  [31]  0.001286  0.0200
# 24  jjlonglpnjx  63749.111652  61775.494501  [31]  0.001242  0.0200
# 25  jjlongiq7tk  64176.977634  61014.043735  [31]  0.001278  0.0200
# 26  jjlongjjlu6  59710.852385  62412.638709  [31]  0.001240  0.0200
# 27  jjlongrfpb8  62184.497833  61774.258639  [31]  0.001234  0.0200
# 28  jjlong22unj  62433.415890  60203.220616  [31]  0.001342  0.0200
# 29  jjlongfccpf  62322.820425  61021.147307  [31]  0.001258  0.0200
# ..          ...           ...           ...   ...       ...     ...
# 70  jjlongab4pc  55925.622940  59055.660365   [0]  0.038246  0.0200
# 71  jjlongtf4sm  62150.830746  59056.558798   [0]  0.037702  0.0200
# 72  jjlong3tn3z  57335.919142  59058.137540   [0]  0.037726  0.0200
# 73  jjlongfpgy4  65301.622868  59056.159457   [0]  0.039245  0.0200
# 74  jjlongke7lo  62628.215313  59056.052167   [0]  0.037465  0.0200
# 75  jjlongkxo8h  56646.868229  59052.831649   [0]  0.037595  0.0200
# 76  jjlong8bmql  58368.057489  59054.577455   [0]  0.039184  0.0200
# 77  jjlongzuu24  61166.845560  59058.213041   [0]  0.041264  0.0200
# 78  jjlongblpk1  66107.642651  59055.069736   [0]  0.040564  0.0200
# 79  jjlonguv1pv  51712.341309  59056.392160   [0]  0.038657  0.0200
# 80  jjlongab4pc  55925.622940  59055.660365   [0]  0.038246  0.0400
# 81  jjlongtf4sm  62150.830746  59056.558798   [0]  0.037702  0.0400
# 82  jjlong3tn3z  57335.919142  59058.137540   [0]  0.037726  0.0400
# 83  jjlongfpgy4  65301.622868  59056.159457   [0]  0.039245  0.0400
# 84  jjlongke7lo  62628.215313  59056.052167   [0]  0.037465  0.0400
# 85  jjlongkxo8h  56646.868229  59052.831649   [0]  0.037595  0.0400
# 86  jjlong8bmql  58368.057489  59054.577455   [0]  0.039184  0.0400
# 87  jjlongzuu24  61166.845560  59058.213041   [0]  0.041264  0.0400
# 88  jjlongblpk1  66107.642651  59055.069736   [0]  0.040564  0.0400
# 89  jjlonguv1pv  51712.341309  59056.392160   [0]  0.038657  0.0400
# 90  jjlongab4pc  55925.622940  59055.660365   [0]  0.038246  0.0133
# 91  jjlongtf4sm  62150.830746  59056.558798   [0]  0.037702  0.0133
# 92  jjlong3tn3z  57335.919142  59058.137540   [0]  0.037726  0.0133
# 93  jjlongfpgy4  65301.622868  59056.159457   [0]  0.039245  0.0133
# 94  jjlongke7lo  62628.215313  59056.052167   [0]  0.037465  0.0133
# 95  jjlongkxo8h  56646.868229  59052.831649   [0]  0.037595  0.0133
# 96  jjlong8bmql  58368.057489  59054.577455   [0]  0.039184  0.0133
# 97  jjlongzuu24  61166.845560  59058.213041   [0]  0.041264  0.0133
# 98  jjlongblpk1  66107.642651  59055.069736   [0]  0.040564  0.0133
# 99  jjlonguv1pv  51712.341309  59056.392160   [0]  0.038657  0.0133
#
# [100 rows x 6 columns]

# %%
fig,ax = plt.subplots(1)
#fig.set_size_inches(10, 4)
df['strategy'] = df['m'].apply(lambda x: 'centralised' if x=='[0]' else 'decentralised')
fig.set_size_inches(6,4)
#ax = sns.stripplot(x="s", y="t", data=df, palette=['#f05f40','#252525']
#                   ,hue='strategy',dodge=0.5, s=5, alpha=0.6,size=4)
sns.stripplot(x="s", y="t", data=df, palette=['#f05f40','#252525']
                   ,hue='strategy',dodge=True)
sns.boxplot(x="s", y="t", data=df, palette=['#f05f40','#252525']
                   ,hue='strategy')
# distance across the "X" or "Y" stipplot column to span, in this case 40%
median_width = 0.2

"""
for tick, text in zip(ax.get_xticks(), ax.get_xticklabels()):
    sample_name = text.get_text()  # "X" or "Y"
    print('sample name: ', sample_name)
    # calculate the median value for all replicates of either X or Y
    matching = df[df['s']==float(sample_name)]
    median_val1 = matching[matching['strategy']=='decentralised']['p'].median()
    median_val2 = matching[matching['strategy']=='centralised']['p'].median()
    print(median_val1)
    # plot horizontal lines across the column, centered on the tick
    if tick == 0:
        ax.plot([tick-median_width/2, tick], [median_val1, median_val1],
                lw=1, color='k',label='predicted')
        ax.plot([tick, tick+median_width/2], [median_val2, median_val2],
                lw=1, color='k')
    else:
        ax.plot([tick-median_width/2, tick], [median_val1, median_val1],
                lw=1, color='k')
        
        ax.plot([tick, tick+median_width/2], [median_val2, median_val2],
                lw=1, color='k')
"""
legend = ax.legend(loc='lower left')
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
sns.despine()
fig.tight_layout()

#fig.savefig('crossover.pdf')
# Out:
# ---------------------------------------------------------
# AttributeError          Traceback (most recent call last)
# <ipython-input-171-0b5abcf392aa> in <module>()
#      34                 lw=1, color='k')
#      35 """
# ---> 36 legend = ax.legend(loc='lower left')
#      37 frame = legend.get_frame()
#      38 frame.set_facecolor('white')
#
# AttributeError: 'FacetGrid' object has no attribute 'legend'
